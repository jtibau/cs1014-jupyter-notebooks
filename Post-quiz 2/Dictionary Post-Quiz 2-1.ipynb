# %%
# %grade_logstart 411

# %% [markdown]
# ## Dictionary Post-Quiz 2-1
#
# You are given a data set representing several weeks of shows on broadway. The data map for this data set is shown below where "Type" refers whether a specific show on broadway was a "Musical", "Play", or "Special". Write an algorithm to compute and print the total number of "Musical" shows on broadway.
#
# In this BlockPy problem there is limited feedback and no indication of whether you have completed the problem successfully. Work on the problem until you believe that you have written a correct algorithm.
#
#
# ![free_response_datamap-1.png](attachment:free_response_datamap-1.png)

# %%
import broadway
report_list = broadway.get_shows()

# %%
# %grade_blockpy 411
# %grade_logstop 411

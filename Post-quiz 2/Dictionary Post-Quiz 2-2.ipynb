# %%
# %grade_logstart 410

# %% [markdown]
# ## Dictionary Post-Quiz 2-2
#
# You are given a data set representing several cultural works in a digital library. The data map for this data set is shown below where "downloads" refers to the number of times a particular work was downloaded and "type" refers to the type of cultural work (e.g. "Text" and "StillImage"). Write an algorithm to plot a histogram of all the works whose "type" is "Text".
#
# In this BlockPy problem there is limited feedback and no indication of whether you have completed the problem successfully. Work on the problem until you believe that you have written a correct algorithm.
#
#
#
# ![free_response_datamap-2.png](attachment:free_response_datamap-2.png)

# %%
import classics

report_list = classics.get_books(test=True)

# %%
# %grade_blockpy 410
# %grade_logstop 410
